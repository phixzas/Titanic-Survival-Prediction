# %% [markdown]
# <h1 style="font-size-3rem;color:red;">Titanic Machine Learning from Disaster</h1>

# %% [markdown]
# <img src="https://images.immediate.co.uk/production/volatile/sites/7/2018/01/TIT011DJ_0-345b632.jpg?quality=90&webp=true&resize=600,400">

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/user/Desktop/Titanic/Data/train (1).csv")

# %%
df['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
df['Survived'].value_counts().plot(
    kind = 'bar',
    color='red')
plt.title('Survival Count', loc='left', size=20)
plt.xlabel('Survived', size=10)
plt.ylabel('No of Passanger', size=10)
plt.show()

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\user\anaconda3\envs\python-starter\python.exe

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\user\anaconda3\envs\python-starter\Lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\user\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 327.5 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/9.3 MB 327.5 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/9.3 MB 327.5 kB/s eta 0:00:27
#    --- ------------------------------------ 0.8/9.3 MB 359.2 kB/s eta 0:00:24
#    --- ------------------------------------ 0.8/9.3 MB 359.2 kB/s eta 0:00:24
#    --- ------------------------------------ 0.8/9.3 MB 359.2 kB/s eta 0:00:24
#    ---- ----------------------------------- 1.0/9.3 MB 389.4 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.0/9.3 MB 389.4 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.0/9.3 MB 389.4 kB/s eta 0:00:22
#    ----- ---------------------------------- 1.3/9.3 MB 401.5 kB/s eta 0:00:20
#    ----- ---------------------------------- 1.3/9.3 MB 401.5 kB/s eta 0:00:20
#    ------ --------------------------------- 1.6/9.3 MB 420.1 kB/s eta 0:00:19
#    ------ --------------------------------- 1.6/9.3 MB 420.1 kB/s eta 0:00:19
#    ------ --------------------------------- 1.6/9.3 MB 420.1 kB/s eta 0:00:19
#    ------- -------------------------------- 1.8/9.3 MB 436.8 kB/s eta 0:00:18
#    -------- ------------------------------- 2.1/9.3 MB 459.6 kB/s eta 0:00:16
#    -------- ------------------------------- 2.1/9.3 MB 459.6 kB/s eta 0:00:16
#    ---------- ----------------------------- 2.4/9.3 MB 475.8 kB/s eta 0:00:15
#    ---------- ----------------------------- 2.4/9.3 MB 475.8 kB/s eta 0:00:15
#    ----------- ---------------------------- 2.6/9.3 MB 493.1 kB/s eta 0:00:14
#    ----------- ---------------------------- 2.6/9.3 MB 493.1 kB/s eta 0:00:14
#    ------------ --------------------------- 2.9/9.3 MB 509.9 kB/s eta 0:00:13
#    ------------ --------------------------- 2.9/9.3 MB 509.9 kB/s eta 0:00:13
#    ------------- -------------------------- 3.1/9.3 MB 526.8 kB/s eta 0:00:12
#    ------------- -------------------------- 3.1/9.3 MB 526.8 kB/s eta 0:00:12
#    ------------- -------------------------- 3.1/9.3 MB 526.8 kB/s eta 0:00:12
#    -------------- ------------------------- 3.4/9.3 MB 505.4 kB/s eta 0:00:12
#    --------------- ------------------------ 3.7/9.3 MB 524.8 kB/s eta 0:00:11
#    ---------------- ----------------------- 3.9/9.3 MB 545.9 kB/s eta 0:00:10
#    ---------------- ----------------------- 3.9/9.3 MB 545.9 kB/s eta 0:00:10
#    ----------------- ---------------------- 4.2/9.3 MB 565.5 kB/s eta 0:00:10
#    ------------------- -------------------- 4.5/9.3 MB 582.8 kB/s eta 0:00:09
#    -------------------- ------------------- 4.7/9.3 MB 600.1 kB/s eta 0:00:08
#    --------------------- ------------------ 5.0/9.3 MB 618.2 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.2/9.3 MB 636.7 kB/s eta 0:00:07
#    ----------------------- ---------------- 5.5/9.3 MB 654.2 kB/s eta 0:00:06
#    ------------------------ --------------- 5.8/9.3 MB 669.2 kB/s eta 0:00:06
#    -------------------------- ------------- 6.3/9.3 MB 702.1 kB/s eta 0:00:05
#    -------------------------- ------------- 6.3/9.3 MB 702.1 kB/s eta 0:00:05
#    ---------------------------- ----------- 6.6/9.3 MB 714.7 kB/s eta 0:00:04
#    ------------------------------ --------- 7.1/9.3 MB 741.9 kB/s eta 0:00:04
#    ------------------------------- -------- 7.3/9.3 MB 757.3 kB/s eta 0:00:03
#    -------------------------------- ------- 7.6/9.3 MB 772.3 kB/s eta 0:00:03
#    ---------------------------------- ----- 8.1/9.3 MB 799.9 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.4/9.3 MB 813.7 kB/s eta 0:00:02
#    ------------------------------------- -- 8.7/9.3 MB 827.2 kB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 852.7 kB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 858.6 kB/s  0:00:11
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.7 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 1.7 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.7 MB/s  0:00:01
# Downloading kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-12.3.0-cp313-cp313-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 1.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.2 MB 1.9 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.2 MB 2.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.8/7.2 MB 2.0 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.2 MB 2.1 MB/s eta 0:00:03
#    --------------- ------------------------ 2.9/7.2 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 3.4/7.2 MB 2.1 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.2 MB 2.1 MB/s eta 0:00:02
#    ------------------------ --------------- 4.5/7.2 MB 2.2 MB/s eta 0:00:02
#    --------------------------- ------------ 5.0/7.2 MB 2.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.2/7.2 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.0/7.2 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 6.6/7.2 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 2.3 MB/s  0:00:03
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\user\anaconda3\envs\python-starter\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
